# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import csv
l=[]
url=BeautifulSoup("https://boardgamegeek.com/market/pricehistory/thing/174430",'html.parser')
soup=requests.get(url)
raw_code = BeautifulSoup(soup.text,"lxml") 
code = raw_code.find_all('tr', class_='ng-scope')
print(raw_code)

# print(DATA)
# Out:
# <html lang="en-US">
# <!DOCTYPE html>
#
# <head>
# <!-- Metadata -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Price History | GeekMarket</title>
# <!-- CSS Files -->
# <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="https://cf.geekdo-static.com/static/geekmarket_master2_64adaabd81345.css" rel="stylesheet" type="text/css"/>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js"></script>
# <base href="/"/>
# </head>
# <body ng-app="geekmarketApp">
# <div ng-class="{printview:pageVars.printView}" ng-controller="GeekMarketCtrl">
# <div id="wrapper">
# <nav class="navbar-default navbar-static-side" role="navigation">
# <div class="sidebar-collapse">
# <ul class="nav" id="side-menu">
# <li>
# <a href="/">
# <i class="fa fa-home"></i> <span class="nav-label">Return to BGG</span>
# </a>
# </li>
# ...
